# %% [markdown]
# ### Loading of Images

# %%
from pathlib import Path
import imghdr
import os
from PIL import Image

data_dir = "hair_types"
image_extensions = [".bmp", ".gif", ".png", ".jpg", ".jpeg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        img_type = imghdr.what(filepath)
        if img_type is None:
            print(f"{filepath} is not an image")
            os.remove(filepath)
        elif img_type not in img_type_accepted_by_tf:
            print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
            os.remove(filepath)
        # else:
        #     img = Image.open(filepath).convert('L')
        #     img.save(filepath)
# Out:
# /var/folders/_2/9tdd0_v908qf2_1bw_19j5wr0000gn/T/ipykernel_69753/3690981329.py:2: DeprecationWarning: 'imghdr' is deprecated and slated for removal in Python 3.13
#   import imghdr

# %% [markdown]
# ### Hyperparameters

# %%
epochs = 50
img_dimensions = (64, 64)
batch_size = 32
learning_rate = 1e-3

# %% [markdown]
# ### Preprocessing

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    validation_split=0.2,
    # width_shift_range=0.2,
    # height_shift_range=0.2,
    # shear_range=0.2,
    # horizontal_flip=True,
    # fill_mode='nearest'
)

train_ds = datagen.flow_from_directory(
    data_dir,
    subset="training",
    seed=1337,
    target_size=img_dimensions,
    batch_size=batch_size,
    shuffle=True,
)

val_ds = datagen.flow_from_directory(
    data_dir,
    subset="validation",
    seed=1337,
    target_size=img_dimensions,
    batch_size=batch_size, 
    shuffle=True,
)
# Out:
# Found 788 images belonging to 3 classes.
# Found 196 images belonging to 3 classes.

# %%
# looking at some sample images
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 10))
images, labels = next(train_ds)
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].astype("uint8"))
    plt.title(int(np.argmax(labels[i])))
    plt.axis("off")
plt.show()

# %% [markdown]
# ### Modelling

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.models import Sequential
from keras.layers import Dense
import pydot as pydot

model = Sequential()
model.add(keras.Input(shape=img_dimensions + (3,))) 

#Normalization
model.add(layers.Rescaling(1.0 / 255))

model.add(layers.Conv2D(filters=16, kernel_size=6, strides=1, padding='valid', dilation_rate=1))
model.add(layers.Activation("relu"))

model.add(layers.Conv2D(filters=32, kernel_size=6, strides=1, padding='valid', dilation_rate=1))
model.add(layers.Activation("relu"))

model.add(layers.Conv2D(filters=64, kernel_size=6, strides=1, padding='valid', dilation_rate=1))
model.add(layers.Activation("relu"))

model.add(layers.Conv2D(filters=128, kernel_size=6, strides=1, padding='valid', dilation_rate=1))
model.add(layers.Activation("relu"))

model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(64))
model.add(layers.Activation("relu"))
model.add(layers.Dense(3))
model.add(layers.Activation("softmax"))

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 59, 59, 16)     │         1,744 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 59, 59, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 54, 54, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 54, 54, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 49, 49, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 49, 49, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 44, 44, 128)    │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 44, 44, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           195 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 3)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 397,491 (1.52 MB)
#  Trainable params: 397,491 (1.52 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Training

# %%
def learning_rate_schedule(epoch):
    initial_lr = learning_rate
    drop = 0.1
    epochs_drop = 12
    lr = initial_lr * np.power(drop, np.floor((1 + epoch) / epochs_drop))
    return lr

history = model.fit(train_ds, epochs=epochs, validation_data=val_ds, 
                    callbacks=[tf.keras.callbacks.EarlyStopping(patience=5),
                                tf.keras.callbacks.LearningRateScheduler(learning_rate_schedule)
                                ]
                    )
# Out:
# Epoch 1/50
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 684ms/step - accuracy: 0.3531 - loss: 1.1020 - val_accuracy: 0.3367 - val_loss: 1.0978 - learning_rate: 0.0010
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 677ms/step - accuracy: 0.3372 - loss: 1.0997 - val_accuracy: 0.4541 - val_loss: 1.0981 - learning_rate: 0.0010
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 665ms/step - accuracy: 0.3355 - loss: 1.0986 - val_accuracy: 0.3367 - val_loss: 1.0967 - learning_rate: 0.0010
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 761ms/step - accuracy: 0.3681 - loss: 1.0903 - val_accuracy: 0.4388 - val_loss: 1.0639 - learning_rate: 0.0010
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 844ms/step - accuracy: 0.3987 - loss: 1.1237 - val_accuracy: 0.4490 - val_loss: 1.0975 - learning_rate: 0.0010
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.4278 - loss: 1.0954 - val_accuracy: 0.4337 - val_loss: 1.0884 - learning_rate: 0.0010
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.4012 - loss: 1.0601 - val_accuracy: 0.3980 - val_loss: 1.0708 - learning_rate: 0.0010
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.4538 - loss: 1.0462 - val_accuracy: 0.3622 - val_loss: 1.0602 - learning_rate: 0.0010
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.4414 - loss: 1.0388 - val_accuracy: 0.4898 - val_loss: 1.0062 - learning_rate: 0.0010
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.5079 - loss: 1.0086 - val_accuracy: 0.5714 - val_loss: 0.9754 - learning_rate: 0.0010
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.5298 - loss: 0.9994 - val_accuracy: 0.5510 - val_loss: 0.9610 - learning_rate: 0.0010
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.5341 - loss: 0.9528 - val_accuracy: 0.5612 - val_loss: 0.9441 - learning_rate: 1.0000e-04
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.5387 - loss: 0.9536 - val_accuracy: 0.6020 - val_loss: 0.9149 - learning_rate: 1.0000e-04
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.5687 - loss: 0.9137 - val_accuracy: 0.6122 - val_loss: 0.9020 - learning_rate: 1.0000e-04
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.5564 - loss: 0.9250 - val_accuracy: 0.6327 - val_loss: 0.8877 - learning_rate: 1.0000e-04
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.5870 - loss: 0.9043 - val_accuracy: 0.6327 - val_loss: 0.8817 - learning_rate: 1.0000e-04
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.5734 - loss: 0.9102 - val_accuracy: 0.6327 - val_loss: 0.8683 - learning_rate: 1.0000e-04
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.5828 - loss: 0.8668 - val_accuracy: 0.6276 - val_loss: 0.8644 - learning_rate: 1.0000e-04
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.5885 - loss: 0.8954 - val_accuracy: 0.6327 - val_loss: 0.8645 - learning_rate: 1.0000e-04
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.6238 - loss: 0.8675 - val_accuracy: 0.6327 - val_loss: 0.8569 - learning_rate: 1.0000e-04
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.5685 - loss: 0.8933 - val_accuracy: 0.6224 - val_loss: 0.8523 - learning_rate: 1.0000e-04
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.5721 - loss: 0.8788 - val_accuracy: 0.6224 - val_loss: 0.8424 - learning_rate: 1.0000e-04
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.5914 - loss: 0.8815 - val_accuracy: 0.6276 - val_loss: 0.8470 - learning_rate: 1.0000e-04
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.6197 - loss: 0.8440 - val_accuracy: 0.6378 - val_loss: 0.8363 - learning_rate: 1.0000e-05
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 997ms/step - accuracy: 0.5852 - loss: 0.8758 - val_accuracy: 0.6327 - val_loss: 0.8346 - learning_rate: 1.0000e-05
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 987ms/step - accuracy: 0.6333 - loss: 0.8108 - val_accuracy: 0.6378 - val_loss: 0.8329 - learning_rate: 1.0000e-05
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 25s 973ms/step - accuracy: 0.6375 - loss: 0.8215 - val_accuracy: 0.6429 - val_loss: 0.8312 - learning_rate: 1.0000e-05
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 24s 938ms/step - accuracy: 0.6003 - loss: 0.8316 - val_accuracy: 0.6429 - val_loss: 0.8308 - learning_rate: 1.0000e-05
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 760ms/step - accuracy: 0.6177 - loss: 0.8243 - val_accuracy: 0.6429 - val_loss: 0.8290 - learning_rate: 1.0000e-05
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 706ms/step - accuracy: 0.6077 - loss: 0.8350 - val_accuracy: 0.6378 - val_loss: 0.8279 - learning_rate: 1.0000e-05
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 773ms/step - accuracy: 0.6262 - loss: 0.8427 - val_accuracy: 0.6378 - val_loss: 0.8267 - learning_rate: 1.0000e-05
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 766ms/step - accuracy: 0.5788 - loss: 0.8677 - val_accuracy: 0.6429 - val_loss: 0.8258 - learning_rate: 1.0000e-05
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 722ms/step - accuracy: 0.5923 - loss: 0.8563 - val_accuracy: 0.6429 - val_loss: 0.8250 - learning_rate: 1.0000e-05
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 748ms/step - accuracy: 0.6308 - loss: 0.8188 - val_accuracy: 0.6480 - val_loss: 0.8237 - learning_rate: 1.0000e-05
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 778ms/step - accuracy: 0.6255 - loss: 0.8210 - val_accuracy: 0.6429 - val_loss: 0.8228 - learning_rate: 1.0000e-05
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 801ms/step - accuracy: 0.5713 - loss: 0.8679 - val_accuracy: 0.6429 - val_loss: 0.8227 - learning_rate: 1.0000e-06
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 796ms/step - accuracy: 0.6362 - loss: 0.8092 - val_accuracy: 0.6429 - val_loss: 0.8227 - learning_rate: 1.0000e-06
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 791ms/step - accuracy: 0.6169 - loss: 0.8257 - val_accuracy: 0.6429 - val_loss: 0.8226 - learning_rate: 1.0000e-06
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 772ms/step - accuracy: 0.6189 - loss: 0.8372 - val_accuracy: 0.6429 - val_loss: 0.8224 - learning_rate: 1.0000e-06
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 748ms/step - accuracy: 0.6072 - loss: 0.8296 - val_accuracy: 0.6429 - val_loss: 0.8224 - learning_rate: 1.0000e-06
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 736ms/step - accuracy: 0.6030 - loss: 0.8449 - val_accuracy: 0.6429 - val_loss: 0.8222 - learning_rate: 1.0000e-06
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 736ms/step - accuracy: 0.6107 - loss: 0.8373 - val_accuracy: 0.6429 - val_loss: 0.8222 - learning_rate: 1.0000e-06
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 743ms/step - accuracy: 0.5941 - loss: 0.8270 - val_accuracy: 0.6429 - val_loss: 0.8220 - learning_rate: 1.0000e-06
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 745ms/step - accuracy: 0.6379 - loss: 0.8083 - val_accuracy: 0.6429 - val_loss: 0.8220 - learning_rate: 1.0000e-06
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 714ms/step - accuracy: 0.6011 - loss: 0.8392 - val_accuracy: 0.6429 - val_loss: 0.8219 - learning_rate: 1.0000e-06
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 670ms/step - accuracy: 0.6293 - loss: 0.8248 - val_accuracy: 0.6429 - val_loss: 0.8218 - learning_rate: 1.0000e-06
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 636ms/step - accuracy: 0.6068 - loss: 0.8315 - val_accuracy: 0.6429 - val_loss: 0.8217 - learning_rate: 1.0000e-06
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 16s 613ms/step - accuracy: 0.5768 - loss: 0.8517 - val_accuracy: 0.6429 - val_loss: 0.8217 - learning_rate: 1.0000e-07
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 16s 601ms/step - accuracy: 0.6355 - loss: 0.7934 - val_accuracy: 0.6429 - val_loss: 0.8217 - learning_rate: 1.0000e-07
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 16s 597ms/step - accuracy: 0.6130 - loss: 0.8106 - val_accuracy: 0.6429 - val_loss: 0.8217 - learning_rate: 1.0000e-07

# %% [markdown]
# ### Visualization

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Sample Prediction

# %%
img = keras.preprocessing.image.load_img(
    "hair_types/Curly_Hair/02dac897d1dec9ba8c057a11d041ada8--layered-natural-hair-natural-black-hairstyles.jpg", target_size=img_dimensions
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)
print(
    "This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions[0])
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# This image is 0.89 percent curly hair, 0.10 percent straight hair, and 0.01 percent wavy hair.

# %%
# Evaluate the model on the validation dataset
evaluation_results = model.evaluate(val_ds)

# Print the evaluation results
print("Validation Loss:", evaluation_results[0])
print("Validation Accuracy:", evaluation_results[1])
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.6336 - loss: 0.8242
# Validation Loss: 0.8216840624809265
# Validation Accuracy: 0.6428571343421936
